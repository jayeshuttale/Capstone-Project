# %% [markdown]
# # Phase 3

# %% [markdown]
# ### 3.1	        Insert records from 42_District_wise_crimes_committed_against_women_2001_2012.csv into a table.

# %% [markdown]
# ![Screenshot%202024-05-20%20133641.png](attachment:Screenshot%202024-05-20%20133641.png)

# %% [markdown]
# ### 3.2	Write SQL query to find the highest number of rapes & Kidnappings that happened in which state, District, and year.

# %% [markdown]
# ### 3.2.1

# %% [markdown]
# ![Screenshot%202024-05-20%20144010.png](attachment:Screenshot%202024-05-20%20144010.png)

# %% [markdown]
# ### 3.2.2

# %% [markdown]
# ![Screenshot%202024-05-20%20144127.png](attachment:Screenshot%202024-05-20%20144127.png)

# %% [markdown]
# ## 3.3	Write SQL query to find All the lowest number of rapes & Kidnappings that happened in which state, District, and year.

# %% [markdown]
# ### 3.3.1

# %% [markdown]
# ![Screenshot%202024-05-20%20134616.png](attachment:Screenshot%202024-05-20%20134616.png)

# %% [markdown]
# ### 3.3.2

# %% [markdown]
# ![Screenshot%202024-05-20%20134705.png](attachment:Screenshot%202024-05-20%20134705.png)

# %% [markdown]
# ## 3.4	Insert records from 02_District_wise_crimes_committed_against_ST_2001_2012.csv into a new table

# %% [markdown]
# ![Screenshot%202024-05-20%20135214.png](attachment:Screenshot%202024-05-20%20135214.png)

# %% [markdown]
# ## 3.5	Write SQL query to find the highest number of dacoity/robbery in which district.

# %% [markdown]
# ### 3.5.1

# %% [markdown]
# ![Screenshot%202024-05-20%20135624.png](attachment:Screenshot%202024-05-20%20135624.png)

# %% [markdown]
# ### 3.5.2

# %% [markdown]
# ![Screenshot%202024-05-20%20135746.png](attachment:Screenshot%202024-05-20%20135746.png)

# %% [markdown]
# ## 3.6	Write SQL query to find in which districts(All) the lowest number of murders happened.

# %% [markdown]
# ![Screenshot%202024-05-20%20135918.png](attachment:Screenshot%202024-05-20%20135918.png)

# %% [markdown]
# ### 3.7	Write SQL query to find the number of murders in ascending order in district and year wise.

# %% [markdown]
# ![Screenshot%202024-05-20%20140437.png](attachment:Screenshot%202024-05-20%20140437.png)

# %% [markdown]
# ## 3.8.1	Insert records of STATE/UT, DISTRICT, YEAR, MURDER, ATTEMPT TO MURDER, and RAPE columns only from 01_District_wise_crimes_committed_IPC_2001_2012.csv into a new table.

# %% [markdown]
# ![Screenshot%202024-05-20%20141653.png](attachment:Screenshot%202024-05-20%20141653.png)

# %% [markdown]
# ## 3.8.2	Write SQL query to find which District in each state/UT has the highest number of murders year wise. Your output should show STATE/UT, YEAR, DISTRICT, and MURDERS.

# %% [markdown]
# ![Screenshot%202024-05-20%20143537.png](attachment:Screenshot%202024-05-20%20143537.png)

# %% [markdown]
# ## 3.8.3	Store the above data (the result of 3.2) in DataFrame and analyze districts that appear 3 or more than 3 years and print the corresponding state/UT, district, murders, and year in descending order.

# %%
import pandas as pd
data_1 = pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\dataset 3.8.2.csv")
data_1.sort_values(by="Rape",ascending=False)
# Out:
#            STATE  Year           DISTRICT  Rape
# 0    WEST BENGAL  2007  24 PARGANAS NORTH   231
# 1    WEST BENGAL  2005  24 PARGANAS NORTH   217
# 2    WEST BENGAL  2011  24 PARGANAS NORTH   203
# 3    WEST BENGAL  2008  24 PARGANAS NORTH   192
# 4    WEST BENGAL  2004  24 PARGANAS NORTH   176
# ..           ...   ...                ...   ...
# 402    MEGHALAYA  2004    GARO HILLS EAST     0
# 401  DAMAN & DIU  2002              DAMAN     0
# 400  LAKSHADWEEP  2001        LAKSHADWEEP     0
# 399  DAMAN & DIU  2001              DAMAN     0
# 419  LAKSHADWEEP  2012        LAKSHADWEEP     0
#
# [420 rows x 4 columns]

# %%
data_2= pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\dataset 3.8.1.csv")
data_2.sort_values(by="Kidnapping_and_Abduction",ascending=False)
# Out:
#              STATE  Year           DISTRICT  Kidnapping_and_Abduction
# 0      WEST BENGAL  2011  24 PARGANAS NORTH                       414
# 1      WEST BENGAL  2012  24 PARGANAS NORTH                       338
# 2    UTTAR PRADESH  2011               AGRA                       328
# 3      WEST BENGAL  2010  24 PARGANAS NORTH                       292
# 4    UTTAR PRADESH  2012               AGRA                       255
# ..             ...   ...                ...                       ...
# 388        MIZORAM  2006             AIZAWL                         0
# 389    LAKSHADWEEP  2006        LAKSHADWEEP                         0
# 390      MEGHALAYA  2007    GARO HILLS EAST                         0
# 391        MIZORAM  2007             AIZAWL                         0
# 419    LAKSHADWEEP  2012        LAKSHADWEEP                         0
#
# [420 rows x 4 columns]

# %% [markdown]
# ## 3.8.4	Use appropriate graphs to show your data (the result of 3.8.3)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(data=data_1,x="Year",y="Rape")
# Out:
# <Axes: xlabel='Year', ylabel='Rape'>

# %% [markdown]
# * we can see that rape case is incresing year by year

# %%
sns.scatterplot(data=data_2,x="Year",y="Kidnapping_and_Abduction")
# Out:
# <Axes: xlabel='Year', ylabel='Kidnapping_and_Abduction'>

# %% [markdown]
# * Also Kidnapping_and_Abduction case is also incresing year on year
